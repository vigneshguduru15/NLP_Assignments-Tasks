# %% [markdown]
# <a href="https://colab.research.google.com/github/vigneshguduru15/NLP_Assignments-Tasks/blob/main/Task_3_chatbot_transformers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task 3: Chatbot using Hugging Face Transformers
#
# This project builds an AI chatbot using Hugging Face transformer models.
#
# Technologies Used:
# - Python
# - Transformers
# - PyTorch
# - Hugging Face

# %%
# !pip install transformers torch

# %%
from transformers import pipeline

# %%
chatbot = pipeline(
    "text-generation",
    model="gpt2"
)

print("Chatbot Loaded Successfully!")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Chatbot Loaded Successfully!

# %%
from transformers import pipeline

# Load chatbot model
chatbot = pipeline(
    "text-generation",
    model="gpt2"
)

print("Chatbot: Hello! I am your AI assistant.")

# Sample questions
questions = [
    "What is NLP?",
    "What is Python?",
    "What is Machine Learning?"
]

# Generate responses
for q in questions:

    print("\nYou:", q)

    response = chatbot(
        q,
        max_new_tokens=20,
        truncation=True,
        pad_token_id=50256
    )

    answer = response[0]['generated_text']

    print("Chatbot:", answer)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Chatbot: Hello! I am your AI assistant.
#
# You: What is NLP?
# Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Chatbot: What is NLP?
#
# ...

# %% [markdown]
# # Conclusion
#
# This project demonstrates how Hugging Face Transformers can be used to build a simple AI chatbot using GPT-2. The chatbot generates human-like responses for user questions using Natural Language Processing techniques.
